# %%
import pandas as pd

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01",end ="2024-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.478998
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.490199
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.386963
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.375157
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.417541
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.600006
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  193.050003
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  193.149994
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.580002
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.529999
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
ticker=["AAPL","SPY","KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01",end ="2024-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498020   87.129951    7.643214  28.520000
# 2010-01-05    6.490199  18.274252   87.360580    7.656429  28.174999
# 2010-01-06    6.386963  18.267769   87.422104    7.534643  28.165001
# 2010-01-07    6.375157  18.222364   87.791115    7.520714  28.094999
# 2010-01-08    6.417541  17.885094   88.083282    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2023-12-22  193.600006  58.320000  473.649994  193.600006  58.320000
# 2023-12-26  193.050003  58.560001  475.649994  193.050003  58.560001
# 2023-12-27  193.149994  58.709999  476.510010  193.149994  58.709999
# 2023-12-28  193.580002  58.750000  476.690002  193.580002  58.750000
# 2023-12-29  192.529999  58.930000  475.309998  192.529999  58.930000
#
# ...

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.478998  18.498020  87.129951  7.643214  28.520000  113.330002
# 2010-01-05  6.490199  18.274252  87.360580  7.656429  28.174999  113.629997
# 2010-01-06  6.386963  18.267769  87.422104  7.534643  28.165001  113.709999
# 2010-01-07  6.375157  18.222364  87.791115  7.520714  28.094999  114.190002
# 2010-01-08  6.417541  17.885094  88.083282  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks = pd.read_csv("btc_1h.csv")

# %%
stocks.head()
# Out:
#               datetime      open      high       low     close      volume
# 0  2018-01-01 05:30:00  13715.65  13715.65  13400.01  13529.01  443.356199
# 1  2018-01-01 06:30:00  13528.99  13595.89  13155.38  13203.06  383.697006
# 2  2018-01-01 07:30:00  13203.00  13418.43  13200.00  13330.18  429.064572
# 3  2018-01-01 08:30:00  13330.26  13611.27  13290.00  13410.03  420.087030
# 4  2018-01-01 09:30:00  13434.98  13623.29  13322.15  13601.01  340.807329

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35664 entries, 0 to 35663
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  35664 non-null  object
#  1   open      35664 non-null  float64
#  2   high      35664 non-null  float64
#  3   low       35664 non-null  float64
#  4   close     35664 non-null  float64
#  5   volume    35664 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 1.6+ MB

# %%
stocks.tail()
# Out:
#                   datetime      open      high       low     close      volume
# 35659  2022-01-31 01:30:00  37512.37  37740.00  37351.63  37684.45  1037.92256
# 35660  2022-01-31 02:30:00  37684.45  37762.60  37492.25  37729.00   874.06052
# 35661  2022-01-31 03:30:00  37729.00  37855.54  37625.41  37785.78   734.65855
# 35662  2022-01-31 04:30:00  37785.78  38230.00  37778.46  37881.76  1728.81180
# 35663  2022-01-31 05:30:00  37881.75  37951.07  36828.32  36829.30  2907.71096

# %%
stocks.to_csv("btc_2h.csv")

# %%
stocks = pd.read_csv("btc_2h.csv")

# %%
stocks
# Out:
#        Unnamed: 0             datetime      open      high       low  \
# 0               0  2018-01-01 05:30:00  13715.65  13715.65  13400.01
# 1               1  2018-01-01 06:30:00  13528.99  13595.89  13155.38
# 2               2  2018-01-01 07:30:00  13203.00  13418.43  13200.00
# 3               3  2018-01-01 08:30:00  13330.26  13611.27  13290.00
# 4               4  2018-01-01 09:30:00  13434.98  13623.29  13322.15
# ...           ...                  ...       ...       ...       ...
# 35659       35659  2022-01-31 01:30:00  37512.37  37740.00  37351.63
# 35660       35660  2022-01-31 02:30:00  37684.45  37762.60  37492.25
# 35661       35661  2022-01-31 03:30:00  37729.00  37855.54  37625.41
# 35662       35662  2022-01-31 04:30:00  37785.78  38230.00  37778.46
# 35663       35663  2022-01-31 05:30:00  37881.75  37951.07  36828.32
#
#           close       volume
# 0      13529.01   443.356199
# 1      13203.06   383.697006
# 2      13330.18   429.064572
# ...

# %%
stocks = pd.read_csv("btc_2h.csv",header=[0,1])

# %%
stocks
# Out:
#       Unnamed: 0_level_0             datetime      open      high       low  \
#                        0  2018-01-01 05:30:00  13715.65  13715.65  13400.01
# 0                      1  2018-01-01 06:30:00  13528.99  13595.89  13155.38
# 1                      2  2018-01-01 07:30:00  13203.00  13418.43  13200.00
# 2                      3  2018-01-01 08:30:00  13330.26  13611.27  13290.00
# 3                      4  2018-01-01 09:30:00  13434.98  13623.29  13322.15
# 4                      5  2018-01-01 10:30:00  13615.20  13699.00  13526.50
# ...                  ...                  ...       ...       ...       ...
# 35658              35659  2022-01-31 01:30:00  37512.37  37740.00  37351.63
# 35659              35660  2022-01-31 02:30:00  37684.45  37762.60  37492.25
# 35660              35661  2022-01-31 03:30:00  37729.00  37855.54  37625.41
# 35661              35662  2022-01-31 04:30:00  37785.78  38230.00  37778.46
# ...

# %%
stocks = pd.read_csv("btc_2h.csv",header=[0,1],index_col=[0])

# %%
stocks
# Out:
#                   datetime      open      high       low     close  \
# 0      2018-01-01 05:30:00  13715.65  13715.65  13400.01  13529.01
# 1      2018-01-01 06:30:00  13528.99  13595.89  13155.38  13203.06
# 2      2018-01-01 07:30:00  13203.00  13418.43  13200.00  13330.18
# 3      2018-01-01 08:30:00  13330.26  13611.27  13290.00  13410.03
# 4      2018-01-01 09:30:00  13434.98  13623.29  13322.15  13601.01
# 5      2018-01-01 10:30:00  13615.20  13699.00  13526.50  13558.99
# ...                    ...       ...       ...       ...       ...
# 35659  2022-01-31 01:30:00  37512.37  37740.00  37351.63  37684.45
# 35660  2022-01-31 02:30:00  37684.45  37762.60  37492.25  37729.00
# 35661  2022-01-31 03:30:00  37729.00  37855.54  37625.41  37785.78
# 35662  2022-01-31 04:30:00  37785.78  38230.00  37778.46  37881.76
# 35663  2022-01-31 05:30:00  37881.75  37951.07  36828.32  36829.30
#
#             volume
# 0       443.356199
# 1       383.697006
# 2       429.064572
# ...

# %%
stocks = pd.read_csv("btc_2h.csv",header=[0,1],index_col=[0],parse_dates=[1])

# %%
stocks
# Out:
#                  datetime      open      high       low     close       volume
# 0     2018-01-01 05:30:00  13715.65  13715.65  13400.01  13529.01   443.356199
# 1     2018-01-01 06:30:00  13528.99  13595.89  13155.38  13203.06   383.697006
# 2     2018-01-01 07:30:00  13203.00  13418.43  13200.00  13330.18   429.064572
# 3     2018-01-01 08:30:00  13330.26  13611.27  13290.00  13410.03   420.087030
# 4     2018-01-01 09:30:00  13434.98  13623.29  13322.15  13601.01   340.807329
# 5     2018-01-01 10:30:00  13615.20  13699.00  13526.50  13558.99   404.229046
# ...                   ...       ...       ...       ...       ...          ...
# 35659 2022-01-31 01:30:00  37512.37  37740.00  37351.63  37684.45  1037.922560
# 35660 2022-01-31 02:30:00  37684.45  37762.60  37492.25  37729.00   874.060520
# 35661 2022-01-31 03:30:00  37729.00  37855.54  37625.41  37785.78   734.658550
# 35662 2022-01-31 04:30:00  37785.78  38230.00  37778.46  37881.76  1728.811800
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('datetime', '2018-01-01 05:30:00'),
#             (    'open',            '13715.65'),
#             (    'high',            '13715.65'),
#             (     'low',            '13400.01'),
#             (   'close',            '13529.01'),
#             (  'volume',          '443.356199')],
#            names=[None, '0'])

# %%
#convert mult index to one tuple
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('datetime', '2018-01-01 05:30:00'),
#                       ('open', '13715.65'),
#                       ('high', '13715.65'),
#                        ('low', '13400.01'),
#                      ('close', '13529.01'),
#                   ('volume', '443.356199')],
#       dtype='object')

# %%
stocks
# Out:
#       (datetime, 2018-01-01 05:30:00)  (open, 13715.65)  (high, 13715.65)  \
# 1                 2018-01-01 06:30:00          13528.99          13595.89
# 2                 2018-01-01 07:30:00          13203.00          13418.43
# 3                 2018-01-01 08:30:00          13330.26          13611.27
# 4                 2018-01-01 09:30:00          13434.98          13623.29
# 5                 2018-01-01 10:30:00          13615.20          13699.00
# ...                               ...               ...               ...
# 35659             2022-01-31 01:30:00          37512.37          37740.00
# 35660             2022-01-31 02:30:00          37684.45          37762.60
# 35661             2022-01-31 03:30:00          37729.00          37855.54
# 35662             2022-01-31 04:30:00          37785.78          38230.00
# 35663             2022-01-31 05:30:00          37881.75          37951.07
#
#        (low, 13400.01)  (close, 13529.01)  (volume, 443.356199)
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#                  datetime      open      high       low     close       volume
#       2018-01-01 05:30:00  13715.65  13715.65  13400.01  13529.01   443.356199
# 1     2018-01-01 06:30:00  13528.99  13595.89  13155.38  13203.06   383.697006
# 2     2018-01-01 07:30:00  13203.00  13418.43  13200.00  13330.18   429.064572
# 3     2018-01-01 08:30:00  13330.26  13611.27  13290.00  13410.03   420.087030
# 4     2018-01-01 09:30:00  13434.98  13623.29  13322.15  13601.01   340.807329
# 5     2018-01-01 10:30:00  13615.20  13699.00  13526.50  13558.99   404.229046
# ...                   ...       ...       ...       ...       ...          ...
# 35659 2022-01-31 01:30:00  37512.37  37740.00  37351.63  37684.45  1037.922560
# 35660 2022-01-31 02:30:00  37684.45  37762.60  37492.25  37729.00   874.060520
# 35661 2022-01-31 03:30:00  37729.00  37855.54  37625.41  37785.78   734.658550
# 35662 2022-01-31 04:30:00  37785.78  38230.00  37778.46  37881.76  1728.811800
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('datetime', '2018-01-01 05:30:00'),
#             (    'open',            '13715.65'),
#             (    'high',            '13715.65'),
#             (     'low',            '13400.01'),
#             (   'close',            '13529.01'),
#             (  'volume',          '443.356199')],
#            )

# %%
stocks.describe()
# Out:
#                             datetime          open          high  \
#                  2018-01-01 05:30:00      13715.65      13715.65
# count                          35663  35663.000000  35663.000000
# mean   2020-01-17 17:24:54.439614976  18808.397509  18919.435484
# min              2018-01-01 06:30:00   3172.620000   3184.750000
# 25%              2019-01-10 08:00:00   7135.875000   7166.715000
# 50%              2020-01-17 23:30:00   9531.830000   9577.010000
# 75%              2021-01-24 05:00:00  32701.090000  32934.235000
# max              2022-01-31 05:30:00  68635.120000  69000.000000
# std                              NaN  17870.790018  17978.183314
#
#                 low         close        volume
#            13400.01      13529.01    443.356199
# count  35663.000000  35663.000000  35663.000000
# mean   18688.895125  18809.049647   2275.114825
# min     3156.260000   3172.050000      0.000000
# 25%     7098.805000   7135.990000   1062.869893
# ...

# %%
Close=stocks.loc[:,"close"].copy()

# %%
Close
# Out:
#        13529.01
# 1      13203.06
# 2      13330.18
# 3      13410.03
# 4      13601.01
# 5      13558.99
# ...         ...
# 35659  37684.45
# 35660  37729.00
# 35661  37785.78
# 35662  37881.76
# 35663  36829.30
#
# [35663 rows x 1 columns]

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %%
Close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
Open=stocks.loc[:,"open"].copy()

# %%
Open
# Out:
#        13715.65
# 1      13528.99
# 2      13203.00
# 3      13330.26
# 4      13434.98
# 5      13615.20
# ...         ...
# 35659  37512.37
# 35660  37684.45
# 35661  37729.00
# 35662  37785.78
# 35663  37881.75
#
# [35663 rows x 1 columns]

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %%
Open.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
High=stocks.loc[:,"high"].copy()

# %%
High
# Out:
#        13715.65
# 1      13595.89
# 2      13418.43
# 3      13611.27
# 4      13623.29
# 5      13699.00
# ...         ...
# 35659  37740.00
# 35660  37762.60
# 35661  37855.54
# 35662  38230.00
# 35663  37951.07
#
# [35663 rows x 1 columns]

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %%
High.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
Low=stocks.loc[:,"low"].copy()

# %%
Low
# Out:
#        13400.01
# 1      13155.38
# 2      13200.00
# 3      13290.00
# 4      13322.15
# 5      13526.50
# ...         ...
# 35659  37351.63
# 35660  37492.25
# 35661  37625.41
# 35662  37778.46
# 35663  36828.32
#
# [35663 rows x 1 columns]

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %%
Low.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
Volume=stocks.loc[:,"volume"].copy()

# %%
Volume
# Out:
#         443.356199
# 1       383.697006
# 2       429.064572
# 3       420.087030
# 4       340.807329
# 5       404.229046
# ...            ...
# 35659  1037.922560
# 35660   874.060520
# 35661   734.658550
# 35662  1728.811800
# 35663  2907.710960
#
# [35663 rows x 1 columns]

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %%
Volume.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()
