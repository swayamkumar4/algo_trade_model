# %%
import pandas as pd

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
bitcoin = yf.download("BTC-USD", start="2018-01-01", end="2022-01-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
bitcoin
# Out:
#                     Open          High           Low         Close  \
# Date
# 2018-01-01  14112.200195  14112.200195  13154.700195  13657.200195
# 2018-01-02  13625.000000  15444.599609  13163.599609  14982.099609
# 2018-01-03  14978.200195  15572.799805  14844.500000  15201.000000
# 2018-01-04  15270.700195  15739.700195  14522.200195  15599.200195
# 2018-01-05  15477.200195  17705.199219  15202.799805  17429.500000
# ...                  ...           ...           ...           ...
# 2022-01-26  36950.515625  38825.410156  36374.906250  36852.121094
# 2022-01-27  36841.878906  37148.324219  35629.281250  37138.234375
# 2022-01-28  37128.445312  37952.878906  36211.109375  37784.332031
# 2022-01-29  37780.714844  38576.261719  37406.472656  38138.179688
# 2022-01-30  38151.917969  38266.339844  37437.710938  37917.601562
#
#                Adj Close       Volume
# Date
# 2018-01-01  13657.200195  10291200000
# 2018-01-02  14982.099609  16846600192
# ...

# %%
ticker=["BTC-USD","USDT-USD","DOGE-USD"]

# %%
stocks = yf.download(ticker, start = "2018-01-01",end ="2022-01-31")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#                Adj Close                             Close            \
#                  BTC-USD  DOGE-USD  USDT-USD       BTC-USD  DOGE-USD
# Date
# 2018-01-01  13657.200195  0.008909  1.007280  13657.200195  0.008909
# 2018-01-02  14982.099609  0.009145  1.004900  14982.099609  0.009145
# 2018-01-03  15201.000000  0.009320  1.013440  15201.000000  0.009320
# 2018-01-04  15599.200195  0.009644  1.002530  15599.200195  0.009644
# 2018-01-05  17429.500000  0.012167  0.998634  17429.500000  0.012167
# ...                  ...       ...       ...           ...       ...
# 2022-01-26  36852.121094  0.143789  1.000630  36852.121094  0.143789
# 2022-01-27  37138.234375  0.141247  1.000344  37138.234375  0.141247
# 2022-01-28  37784.332031  0.141656  1.000345  37784.332031  0.141656
# 2022-01-29  38138.179688  0.143056  1.000362  38138.179688  0.143056
# 2022-01-30  37917.601562  0.139471  1.000341  37917.601562  0.139471
#
# ...

# %%
stocks.head()
# Out:
#                Adj Close                             Close            \
#                  BTC-USD  DOGE-USD  USDT-USD       BTC-USD  DOGE-USD
# Date
# 2018-01-01  13657.200195  0.008909  1.007280  13657.200195  0.008909
# 2018-01-02  14982.099609  0.009145  1.004900  14982.099609  0.009145
# 2018-01-03  15201.000000  0.009320  1.013440  15201.000000  0.009320
# 2018-01-04  15599.200195  0.009644  1.002530  15599.200195  0.009644
# 2018-01-05  17429.500000  0.012167  0.998634  17429.500000  0.012167
#
#                               High                              Low            \
#             USDT-USD       BTC-USD  DOGE-USD USDT-USD       BTC-USD  DOGE-USD
# Date
# 2018-01-01  1.007280  14112.200195  0.009063  1.01536  13154.700195  0.008101
# 2018-01-02  1.004900  15444.599609  0.009598  1.00988  13163.599609  0.008551
# 2018-01-03  1.013440  15572.799805  0.009584  1.02328  14844.500000  0.008882
# 2018-01-04  1.002530  15739.700195  0.010036  1.01618  14522.200195  0.008768
# ...

# %%
stocks.tail()
# Out:
#                Adj Close                             Close            \
#                  BTC-USD  DOGE-USD  USDT-USD       BTC-USD  DOGE-USD
# Date
# 2022-01-26  36852.121094  0.143789  1.000630  36852.121094  0.143789
# 2022-01-27  37138.234375  0.141247  1.000344  37138.234375  0.141247
# 2022-01-28  37784.332031  0.141656  1.000345  37784.332031  0.141656
# 2022-01-29  38138.179688  0.143056  1.000362  38138.179688  0.143056
# 2022-01-30  37917.601562  0.139471  1.000341  37917.601562  0.139471
#
#                               High                               Low  \
#             USDT-USD       BTC-USD  DOGE-USD  USDT-USD       BTC-USD
# Date
# 2022-01-26  1.000630  38825.410156  0.152603  1.001117  36374.906250
# 2022-01-27  1.000344  37148.324219  0.145010  1.000859  35629.281250
# 2022-01-28  1.000345  37952.878906  0.142413  1.000723  36211.109375
# 2022-01-29  1.000362  38576.261719  0.143984  1.000633  37406.472656
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1491 entries, 2018-01-01 to 2022-01-30
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BTC-USD)   1491 non-null   float64
#  1   (Adj Close, DOGE-USD)  1491 non-null   float64
#  2   (Adj Close, USDT-USD)  1491 non-null   float64
#  3   (Close, BTC-USD)       1491 non-null   float64
#  4   (Close, DOGE-USD)      1491 non-null   float64
#  5   (Close, USDT-USD)      1491 non-null   float64
#  6   (High, BTC-USD)        1491 non-null   float64
#  7   (High, DOGE-USD)       1491 non-null   float64
#  8   (High, USDT-USD)       1491 non-null   float64
#  9   (Low, BTC-USD)         1491 non-null   float64
#  10  (Low, DOGE-USD)        1491 non-null   float64
#  11  (Low, USDT-USD)        1491 non-null   float64
#  12  (Open, BTC-USD)        1491 non-null   float64
#  13  (Open, DOGE-USD)       1491 non-null   float64
# ...

# %%
stocks.to_csv("btc_1h.csv")

# %%
stocks = pd.read_csv("btc_1h.csv")

# %%
stocks
# Out:
#       Unnamed: 0         Adj Close           Adj Close.1         Adj Close.2  \
# 0            NaN           BTC-USD              DOGE-USD            USDT-USD
# 1           Date               NaN                   NaN                 NaN
# 2     2018-01-01  13657.2001953125   0.00890900008380413  1.0072799921035767
# 3     2018-01-02   14982.099609375  0.009145000018179417  1.0048999786376953
# 4     2018-01-03           15201.0  0.009320000186562538  1.0134400129318237
# ...          ...               ...                   ...                 ...
# 1488  2022-01-26    36852.12109375   0.14378899335861206  1.0006300210952759
# 1489  2022-01-27      37138.234375    0.1412470042705536  1.0003440380096436
# 1490  2022-01-28    37784.33203125   0.14165599644184113    1.00034499168396
# 1491  2022-01-29     38138.1796875    0.1430560052394867  1.0003620386123657
# 1492  2022-01-30     37917.6015625   0.13947099447250366  1.0003410577774048
#
# ...

# %%
stocks = pd.read_csv("btc_1h.csv",header=[0,1])
stocks
# Out:
#      Unnamed: 0_level_0     Adj Close                             Close  \
#      Unnamed: 0_level_1       BTC-USD  DOGE-USD  USDT-USD       BTC-USD
# 0                  Date           NaN       NaN       NaN           NaN
# 1            2018-01-01  13657.200195  0.008909  1.007280  13657.200195
# 2            2018-01-02  14982.099609  0.009145  1.004900  14982.099609
# 3            2018-01-03  15201.000000  0.009320  1.013440  15201.000000
# 4            2018-01-04  15599.200195  0.009644  1.002530  15599.200195
# ...                 ...           ...       ...       ...           ...
# 1487         2022-01-26  36852.121094  0.143789  1.000630  36852.121094
# 1488         2022-01-27  37138.234375  0.141247  1.000344  37138.234375
# 1489         2022-01-28  37784.332031  0.141656  1.000345  37784.332031
# 1490         2022-01-29  38138.179688  0.143056  1.000362  38138.179688
# 1491         2022-01-30  37917.601562  0.139471  1.000341  37917.601562
#
# ...

# %%
stocks = pd.read_csv("btc_1h.csv",header=[0,1],index_col=[0])
stocks
# Out:
#                Adj Close                             Close            \
#                  BTC-USD  DOGE-USD  USDT-USD       BTC-USD  DOGE-USD
# Date
# 2018-01-01  13657.200195  0.008909  1.007280  13657.200195  0.008909
# 2018-01-02  14982.099609  0.009145  1.004900  14982.099609  0.009145
# 2018-01-03  15201.000000  0.009320  1.013440  15201.000000  0.009320
# 2018-01-04  15599.200195  0.009644  1.002530  15599.200195  0.009644
# 2018-01-05  17429.500000  0.012167  0.998634  17429.500000  0.012167
# ...                  ...       ...       ...           ...       ...
# 2022-01-26  36852.121094  0.143789  1.000630  36852.121094  0.143789
# 2022-01-27  37138.234375  0.141247  1.000344  37138.234375  0.141247
# 2022-01-28  37784.332031  0.141656  1.000345  37784.332031  0.141656
# 2022-01-29  38138.179688  0.143056  1.000362  38138.179688  0.143056
# 2022-01-30  37917.601562  0.139471  1.000341  37917.601562  0.139471
#
# ...

# %%
stocks = pd.read_csv("btc_1h.csv",header=[0,1],index_col=[0], parse_dates=[0])
stocks
# Out:
#                Adj Close                             Close            \
#                  BTC-USD  DOGE-USD  USDT-USD       BTC-USD  DOGE-USD
# Date
# 2018-01-01  13657.200195  0.008909  1.007280  13657.200195  0.008909
# 2018-01-02  14982.099609  0.009145  1.004900  14982.099609  0.009145
# 2018-01-03  15201.000000  0.009320  1.013440  15201.000000  0.009320
# 2018-01-04  15599.200195  0.009644  1.002530  15599.200195  0.009644
# 2018-01-05  17429.500000  0.012167  0.998634  17429.500000  0.012167
# ...                  ...       ...       ...           ...       ...
# 2022-01-26  36852.121094  0.143789  1.000630  36852.121094  0.143789
# 2022-01-27  37138.234375  0.141247  1.000344  37138.234375  0.141247
# 2022-01-28  37784.332031  0.141656  1.000345  37784.332031  0.141656
# 2022-01-29  38138.179688  0.143056  1.000362  38138.179688  0.143056
# 2022-01-30  37917.601562  0.139471  1.000341  37917.601562  0.139471
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',  'BTC-USD'),
#             ('Adj Close', 'DOGE-USD'),
#             ('Adj Close', 'USDT-USD'),
#             (    'Close',  'BTC-USD'),
#             (    'Close', 'DOGE-USD'),
#             (    'Close', 'USDT-USD'),
#             (     'High',  'BTC-USD'),
#             (     'High', 'DOGE-USD'),
#             (     'High', 'USDT-USD'),
#             (      'Low',  'BTC-USD'),
#             (      'Low', 'DOGE-USD'),
#             (      'Low', 'USDT-USD'),
#             (     'Open',  'BTC-USD'),
#             (     'Open', 'DOGE-USD'),
#             (     'Open', 'USDT-USD'),
#             (   'Volume',  'BTC-USD'),
#             (   'Volume', 'DOGE-USD'),
#             (   'Volume', 'USDT-USD')],
#            )

# %%
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([ ('Adj Close', 'BTC-USD'), ('Adj Close', 'DOGE-USD'),
#        ('Adj Close', 'USDT-USD'),      ('Close', 'BTC-USD'),
#            ('Close', 'DOGE-USD'),     ('Close', 'USDT-USD'),
#              ('High', 'BTC-USD'),      ('High', 'DOGE-USD'),
#             ('High', 'USDT-USD'),        ('Low', 'BTC-USD'),
#              ('Low', 'DOGE-USD'),       ('Low', 'USDT-USD'),
#              ('Open', 'BTC-USD'),      ('Open', 'DOGE-USD'),
#             ('Open', 'USDT-USD'),     ('Volume', 'BTC-USD'),
#           ('Volume', 'DOGE-USD'),    ('Volume', 'USDT-USD')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, BTC-USD)  (Adj Close, DOGE-USD)  \
# Date
# 2018-01-01          13657.200195               0.008909
# 2018-01-02          14982.099609               0.009145
# 2018-01-03          15201.000000               0.009320
# 2018-01-04          15599.200195               0.009644
# 2018-01-05          17429.500000               0.012167
# ...                          ...                    ...
# 2022-01-26          36852.121094               0.143789
# 2022-01-27          37138.234375               0.141247
# 2022-01-28          37784.332031               0.141656
# 2022-01-29          38138.179688               0.143056
# 2022-01-30          37917.601562               0.139471
#
#             (Adj Close, USDT-USD)  (Close, BTC-USD)  (Close, DOGE-USD)  \
# Date
# 2018-01-01               1.007280      13657.200195           0.008909
# 2018-01-02               1.004900      14982.099609           0.009145
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#                Adj Close                             Close            \
#                  BTC-USD  DOGE-USD  USDT-USD       BTC-USD  DOGE-USD
# Date
# 2018-01-01  13657.200195  0.008909  1.007280  13657.200195  0.008909
# 2018-01-02  14982.099609  0.009145  1.004900  14982.099609  0.009145
# 2018-01-03  15201.000000  0.009320  1.013440  15201.000000  0.009320
# 2018-01-04  15599.200195  0.009644  1.002530  15599.200195  0.009644
# 2018-01-05  17429.500000  0.012167  0.998634  17429.500000  0.012167
# ...                  ...       ...       ...           ...       ...
# 2022-01-26  36852.121094  0.143789  1.000630  36852.121094  0.143789
# 2022-01-27  37138.234375  0.141247  1.000344  37138.234375  0.141247
# 2022-01-28  37784.332031  0.141656  1.000345  37784.332031  0.141656
# 2022-01-29  38138.179688  0.143056  1.000362  38138.179688  0.143056
# 2022-01-30  37917.601562  0.139471  1.000341  37917.601562  0.139471
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',  'BTC-USD'),
#             ('Adj Close', 'DOGE-USD'),
#             ('Adj Close', 'USDT-USD'),
#             (    'Close',  'BTC-USD'),
#             (    'Close', 'DOGE-USD'),
#             (    'Close', 'USDT-USD'),
#             (     'High',  'BTC-USD'),
#             (     'High', 'DOGE-USD'),
#             (     'High', 'USDT-USD'),
#             (      'Low',  'BTC-USD'),
#             (      'Low', 'DOGE-USD'),
#             (      'Low', 'USDT-USD'),
#             (     'Open',  'BTC-USD'),
#             (     'Open', 'DOGE-USD'),
#             (     'Open', 'USDT-USD'),
#             (   'Volume',  'BTC-USD'),
#             (   'Volume', 'DOGE-USD'),
#             (   'Volume', 'USDT-USD')],
#            )

# %%
stocks.describe()
# Out:
#           Adj Close                                   Close               \
#             BTC-USD     DOGE-USD     USDT-USD       BTC-USD     DOGE-USD
# count   1491.000000  1491.000000  1491.000000   1491.000000  1491.000000
# mean   18834.535578     0.055636     1.001655  18834.535578     0.055636
# std    17877.281815     0.107687     0.005617  17877.281815     0.107687
# min     3236.761719     0.001537     0.966644   3236.761719     0.001537
# 25%     7182.919678     0.002510     1.000019   7182.919678     0.002510
# 50%     9538.024414     0.003197     1.000770   9538.024414     0.003197
# 75%    32742.024414     0.013079     1.003009  32742.024414     0.013079
# max    67566.828125     0.684777     1.053585  67566.828125     0.684777
#
#                             High                                     Low  \
#           USDT-USD       BTC-USD     DOGE-USD     USDT-USD       BTC-USD
# count  1491.000000   1491.000000  1491.000000  1491.000000   1491.000000
# ...

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close['BTC-USD']
# Out:
# Date
# 2018-01-01    13657.200195
# 2018-01-02    14982.099609
# 2018-01-03    15201.000000
# 2018-01-04    15599.200195
# 2018-01-05    17429.500000
#                   ...
# 2022-01-26    36852.121094
# 2022-01-27    37138.234375
# 2022-01-28    37784.332031
# 2022-01-29    38138.179688
# 2022-01-30    37917.601562
# Name: BTC-USD, Length: 1491, dtype: float64

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 13657.2001953125

# %%
close['BTC-USD']
# Out:
# Date
# 2018-01-01    13657.200195
# 2018-01-02    14982.099609
# 2018-01-03    15201.000000
# 2018-01-04    15599.200195
# 2018-01-05    17429.500000
#                   ...
# 2022-01-26    36852.121094
# 2022-01-27    37138.234375
# 2022-01-28    37784.332031
# 2022-01-29    38138.179688
# 2022-01-30    37917.601562
# Name: BTC-USD, Length: 1491, dtype: float64

# %%
close['BTC-USD'].div(close.iloc[0,0])
# Out:
# Date
# 2018-01-01    1.000000
# 2018-01-02    1.097011
# 2018-01-03    1.113039
# 2018-01-04    1.142196
# 2018-01-05    1.276213
#                 ...
# 2022-01-26    2.698366
# 2022-01-27    2.719315
# 2022-01-28    2.766624
# 2022-01-29    2.792533
# 2022-01-30    2.776382
# Name: BTC-USD, Length: 1491, dtype: float64

# %%
close['BTC-USD'].div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2018-01-01    100.000000
# 2018-01-02    109.701106
# 2018-01-03    111.303926
# 2018-01-04    114.219606
# 2018-01-05    127.621326
#                  ...
# 2022-01-26    269.836574
# 2022-01-27    271.931537
# 2022-01-28    276.662358
# 2022-01-29    279.253281
# 2022-01-30    277.638176
# Name: BTC-USD, Length: 1491, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                BTC-USD     DOGE-USD    USDT-USD
# Date
# 2018-01-01  100.000000   100.000000  100.000000
# 2018-01-02  109.701106   102.649006   99.763719
# 2018-01-03  111.303926   104.613313  100.611550
# 2018-01-04  114.219606   108.250082   99.528432
# 2018-01-05  127.621326   136.569762   99.141648
# ...                ...          ...         ...
# 2022-01-26  269.836574  1613.974543   99.339809
# 2022-01-27  271.931537  1585.441721   99.311417
# 2022-01-28  276.662358  1590.032496   99.311512
# 2022-01-29  279.253281  1605.747041   99.313205
# 2022-01-30  277.638176  1565.506714   99.311122
#
# [1491 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
btc_usd= close['BTC-USD'].copy().to_frame()

# %%
btc_usd
# Out:
#                  BTC-USD
# Date
# 2018-01-01  13657.200195
# 2018-01-02  14982.099609
# 2018-01-03  15201.000000
# 2018-01-04  15599.200195
# 2018-01-05  17429.500000
# ...                  ...
# 2022-01-26  36852.121094
# 2022-01-27  37138.234375
# 2022-01-28  37784.332031
# 2022-01-29  38138.179688
# 2022-01-30  37917.601562
#
# [1491 rows x 1 columns]

# %%
btc_usd.shift(periods=1)
# Out:
#                  BTC-USD
# Date
# 2018-01-01           NaN
# 2018-01-02  13657.200195
# 2018-01-03  14982.099609
# 2018-01-04  15201.000000
# 2018-01-05  15599.200195
# ...                  ...
# 2022-01-26  36954.003906
# 2022-01-27  36852.121094
# 2022-01-28  37138.234375
# 2022-01-29  37784.332031
# 2022-01-30  38138.179688
#
# [1491 rows x 1 columns]

# %%
btc_usd["lag1"]=btc_usd.shift(periods=1)

# %%
btc_usd
# Out:
#                  BTC-USD          lag1
# Date
# 2018-01-01  13657.200195           NaN
# 2018-01-02  14982.099609  13657.200195
# 2018-01-03  15201.000000  14982.099609
# 2018-01-04  15599.200195  15201.000000
# 2018-01-05  17429.500000  15599.200195
# ...                  ...           ...
# 2022-01-26  36852.121094  36954.003906
# 2022-01-27  37138.234375  36852.121094
# 2022-01-28  37784.332031  37138.234375
# 2022-01-29  38138.179688  37784.332031
# 2022-01-30  37917.601562  38138.179688
#
# [1491 rows x 2 columns]

# %%
btc_usd["Diff"] = btc_usd['BTC-USD'].sub(btc_usd['BTC-USD'].shift(1))

# %%
btc_usd
# Out:
#                  BTC-USD          lag1         Diff
# Date
# 2018-01-01  13657.200195           NaN          NaN
# 2018-01-02  14982.099609  13657.200195  1324.899414
# 2018-01-03  15201.000000  14982.099609   218.900391
# 2018-01-04  15599.200195  15201.000000   398.200195
# 2018-01-05  17429.500000  15599.200195  1830.299805
# ...                  ...           ...          ...
# 2022-01-26  36852.121094  36954.003906  -101.882812
# 2022-01-27  37138.234375  36852.121094   286.113281
# 2022-01-28  37784.332031  37138.234375   646.097656
# 2022-01-29  38138.179688  37784.332031   353.847656
# 2022-01-30  37917.601562  38138.179688  -220.578125
#
# [1491 rows x 3 columns]

# %%
btc_usd["% Change"]=btc_usd['BTC-USD'].div(btc_usd.lag1).sub(1).mul(100)

# %%
btc_usd
# Out:
#                  BTC-USD          lag1         Diff   % Change
# Date
# 2018-01-01  13657.200195           NaN          NaN        NaN
# 2018-01-02  14982.099609  13657.200195  1324.899414   9.701106
# 2018-01-03  15201.000000  14982.099609   218.900391   1.461080
# 2018-01-04  15599.200195  15201.000000   398.200195   2.619566
# 2018-01-05  17429.500000  15599.200195  1830.299805  11.733293
# ...                  ...           ...          ...        ...
# 2022-01-26  36852.121094  36954.003906  -101.882812  -0.275702
# 2022-01-27  37138.234375  36852.121094   286.113281   0.776382
# 2022-01-28  37784.332031  37138.234375   646.097656   1.739710
# 2022-01-29  38138.179688  37784.332031   353.847656   0.936493
# 2022-01-30  37917.601562  38138.179688  -220.578125  -0.578366
#
# [1491 rows x 4 columns]

# %%
btc_usd["Diff2"]=btc_usd['BTC-USD'].diff(periods=1)
btc_usd
# Out:
#                  BTC-USD          lag1         Diff   % Change        Diff2
# Date
# 2018-01-01  13657.200195           NaN          NaN        NaN          NaN
# 2018-01-02  14982.099609  13657.200195  1324.899414   9.701106  1324.899414
# 2018-01-03  15201.000000  14982.099609   218.900391   1.461080   218.900391
# 2018-01-04  15599.200195  15201.000000   398.200195   2.619566   398.200195
# 2018-01-05  17429.500000  15599.200195  1830.299805  11.733293  1830.299805
# ...                  ...           ...          ...        ...          ...
# 2022-01-26  36852.121094  36954.003906  -101.882812  -0.275702  -101.882812
# 2022-01-27  37138.234375  36852.121094   286.113281   0.776382   286.113281
# 2022-01-28  37784.332031  37138.234375   646.097656   1.739710   646.097656
# 2022-01-29  38138.179688  37784.332031   353.847656   0.936493   353.847656
# 2022-01-30  37917.601562  38138.179688  -220.578125  -0.578366  -220.578125
#
# [1491 rows x 5 columns]

# %%
btc_usd["% Change 2"]=btc_usd['BTC-USD'].pct_change(periods=1).mul(100)

# %%
btc_usd
# Out:
#                  BTC-USD          lag1         Diff   % Change        Diff2  \
# Date
# 2018-01-01  13657.200195           NaN          NaN        NaN          NaN
# 2018-01-02  14982.099609  13657.200195  1324.899414   9.701106  1324.899414
# 2018-01-03  15201.000000  14982.099609   218.900391   1.461080   218.900391
# 2018-01-04  15599.200195  15201.000000   398.200195   2.619566   398.200195
# 2018-01-05  17429.500000  15599.200195  1830.299805  11.733293  1830.299805
# ...                  ...           ...          ...        ...          ...
# 2022-01-26  36852.121094  36954.003906  -101.882812  -0.275702  -101.882812
# 2022-01-27  37138.234375  36852.121094   286.113281   0.776382   286.113281
# 2022-01-28  37784.332031  37138.234375   646.097656   1.739710   646.097656
# 2022-01-29  38138.179688  37784.332031   353.847656   0.936493   353.847656
# 2022-01-30  37917.601562  38138.179688  -220.578125  -0.578366  -220.578125
#
#             % Change 2
# Date
# ...

# %%
del btc_usd["% Change"]

# %%
btc_usd
# Out:
#                  BTC-USD          lag1         Diff        Diff2  % Change 2
# Date
# 2018-01-01  13657.200195           NaN          NaN          NaN         NaN
# 2018-01-02  14982.099609  13657.200195  1324.899414  1324.899414    9.701106
# 2018-01-03  15201.000000  14982.099609   218.900391   218.900391    1.461080
# 2018-01-04  15599.200195  15201.000000   398.200195   398.200195    2.619566
# 2018-01-05  17429.500000  15599.200195  1830.299805  1830.299805   11.733293
# ...                  ...           ...          ...          ...         ...
# 2022-01-26  36852.121094  36954.003906  -101.882812  -101.882812   -0.275702
# 2022-01-27  37138.234375  36852.121094   286.113281   286.113281    0.776382
# 2022-01-28  37784.332031  37138.234375   646.097656   646.097656    1.739710
# 2022-01-29  38138.179688  37784.332031   353.847656   353.847656    0.936493
# 2022-01-30  37917.601562  38138.179688  -220.578125  -220.578125   -0.578366
#
# [1491 rows x 5 columns]

# %%
btc_usd.rename(columns = {'% Change 2':'Change'}, inplace = True)

# %%
btc_usd
# Out:
#                  BTC-USD          lag1         Diff        Diff2     Change
# Date
# 2018-01-01  13657.200195           NaN          NaN          NaN        NaN
# 2018-01-02  14982.099609  13657.200195  1324.899414  1324.899414   9.701106
# 2018-01-03  15201.000000  14982.099609   218.900391   218.900391   1.461080
# 2018-01-04  15599.200195  15201.000000   398.200195   398.200195   2.619566
# 2018-01-05  17429.500000  15599.200195  1830.299805  1830.299805  11.733293
# ...                  ...           ...          ...          ...        ...
# 2022-01-26  36852.121094  36954.003906  -101.882812  -101.882812  -0.275702
# 2022-01-27  37138.234375  36852.121094   286.113281   286.113281   0.776382
# 2022-01-28  37784.332031  37138.234375   646.097656   646.097656   1.739710
# 2022-01-29  38138.179688  37784.332031   353.847656   353.847656   0.936493
# 2022-01-30  37917.601562  38138.179688  -220.578125  -220.578125  -0.578366
#
# [1491 rows x 5 columns]

# %%
btc_usd['BTC-USD'].resample("M").last()
# Out:
# Date
# 2018-01-31    10221.099609
# 2018-02-28    10397.900391
# 2018-03-31     6973.529785
# 2018-04-30     9240.549805
# 2018-05-31     7494.169922
# 2018-06-30     6404.000000
# 2018-07-31     7780.439941
# 2018-08-31     7037.580078
# 2018-09-30     6625.560059
# 2018-10-31     6317.609863
# 2018-11-30     4017.268555
# 2018-12-31     3742.700439
# 2019-01-31     3457.792725
# 2019-02-28     3854.785400
# 2019-03-31     4105.404297
# 2019-04-30     5350.726562
# 2019-05-31     8574.501953
# 2019-06-30    10817.155273
# 2019-07-31    10085.627930
# 2019-08-31     9630.664062
# 2019-09-30     8293.868164
# 2019-10-31     9199.584961
# 2019-11-30     7569.629883
# 2019-12-31     7193.599121
# 2020-01-31     9350.529297
# 2020-02-29     8599.508789
# 2020-03-31     6438.644531
# 2020-04-30     8658.553711
# 2020-05-31     9461.058594
# 2020-06-30     9137.993164
# 2020-07-31    11323.466797
# 2020-08-31    11680.820312
# 2020-09-30    10784.491211
# 2020-10-31    13780.995117
# ...

# %%
btc_usd['BTC-USD'].resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2018-01-31          NaN
# 2018-02-28     1.729763
# 2018-03-30   -33.731621
# 2018-04-30    34.105260
# 2018-05-31   -18.899091
# 2018-06-29   -17.024836
# 2018-07-31    25.121660
# 2018-08-31    -9.547787
# 2018-09-28    -5.590703
# 2018-10-31    -4.914414
# 2018-11-30   -36.411576
# 2018-12-31    -6.834697
# 2019-01-31    -7.612357
# 2019-02-28    11.481101
# 2019-03-29     6.319135
# 2019-04-30    30.557287
# 2019-05-31    60.249302
# 2019-06-28    44.700323
# 2019-07-31   -18.712356
# 2019-08-30    -4.833156
# 2019-09-30   -13.589102
# 2019-10-31    10.920318
# 2019-11-29   -15.634850
# 2019-12-31    -7.313835
# 2020-01-31    29.984020
# 2020-02-28    -7.251720
# 2020-03-31   -25.757534
# 2020-04-30    34.477896
# 2020-05-29     9.015020
# 2020-06-30    -3.190242
# 2020-07-31    23.916341
# 2020-08-31     3.155867
# 2020-09-30    -7.673512
# 2020-10-30    25.611141
# 2020-11-30    44.877300
# 2020-12-31    47.773174
# 2021-01-29    18.325347
# 2021-02-26    35.036833
# ...

# %%
btc_usd
# Out:
#                  BTC-USD          lag1         Diff        Diff2     Change
# Date
# 2018-01-01  13657.200195           NaN          NaN          NaN        NaN
# 2018-01-02  14982.099609  13657.200195  1324.899414  1324.899414   9.701106
# 2018-01-03  15201.000000  14982.099609   218.900391   218.900391   1.461080
# 2018-01-04  15599.200195  15201.000000   398.200195   398.200195   2.619566
# 2018-01-05  17429.500000  15599.200195  1830.299805  1830.299805  11.733293
# ...                  ...           ...          ...          ...        ...
# 2022-01-26  36852.121094  36954.003906  -101.882812  -101.882812  -0.275702
# 2022-01-27  37138.234375  36852.121094   286.113281   286.113281   0.776382
# 2022-01-28  37784.332031  37138.234375   646.097656   646.097656   1.739710
# 2022-01-29  38138.179688  37784.332031   353.847656   353.847656   0.936493
# 2022-01-30  37917.601562  38138.179688  -220.578125  -220.578125  -0.578366
#
# [1491 rows x 5 columns]

# %%
del btc_usd["Change"]
del btc_usd["Diff2"]
del btc_usd["Diff"]
del btc_usd["lag1"]

# %%
btc_usd
# Out:
#                  BTC-USD
# Date
# 2018-01-01  13657.200195
# 2018-01-02  14982.099609
# 2018-01-03  15201.000000
# 2018-01-04  15599.200195
# 2018-01-05  17429.500000
# ...                  ...
# 2022-01-26  36852.121094
# 2022-01-27  37138.234375
# 2022-01-28  37784.332031
# 2022-01-29  38138.179688
# 2022-01-30  37917.601562
#
# [1491 rows x 1 columns]

# %%
ret = btc_usd.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1490 entries, 2018-01-02 to 2022-01-30
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BTC-USD  1490 non-null   float64
# dtypes: float64(1)
# memory usage: 23.3 KB

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# BTC-USD    0.001477
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# BTC-USD    0.001554
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)
std_daily
# Out:
# BTC-USD    0.039424
# dtype: float64

# %%
ret.std()
# Out:
# BTC-USD    0.039424
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# BTC-USD    0.372214
# dtype: float64

# %%
annual_var_return=var_daily*252
annual_var_return
# Out:
# BTC-USD    0.391674
# dtype: float64

# %%
annual_std_retuens=np.sqrt(annual_var_return)
annual_std_retuens
# Out:
# BTC-USD    0.625839
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# BTC-USD    0.625839
# dtype: float64

# %%
ticker=["USDT-USD","BTC-USD","DOGE-USD","BNB-USD","ETH-USD","ONE-USD"]

# %%
stocks = yf.download(ticker, start = "2018-01-01",end ="2022-01-31")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#              BNB-USD   BTC-USD  DOGE-USD   ETH-USD   ONE-USD  USDT-USD
# Date
# 2018-01-02  0.050289  0.097011  0.026490  0.144702  0.044919 -0.002363
# 2018-01-03  0.078992  0.014611  0.019136  0.088503 -0.109649  0.008498
# 2018-01-04 -0.033756  0.026196  0.034764  0.018907  0.100310 -0.010765
# 2018-01-05  0.618973  0.117333  0.261613  0.017125  0.087624 -0.003886
# 2018-01-06  0.525742  0.005594  0.221583  0.044061  0.384758  0.010370

# %%
ret.describe().T
# Out:
#            count      mean       std       min       25%       50%       75%  \
# BNB-USD   1490.0  0.004411  0.062399 -0.419046 -0.022929  0.001070  0.029310
# BTC-USD   1490.0  0.001477  0.039424 -0.371695 -0.015564  0.001388  0.018168
# DOGE-USD  1490.0  0.005814  0.119581 -0.402570 -0.024116 -0.001371  0.019008
# ETH-USD   1490.0  0.002144  0.050973 -0.423472 -0.021422  0.001101  0.027832
# ONE-USD   1490.0  0.001235  0.095922 -0.996362 -0.014915  0.000000  0.008223
# USDT-USD  1490.0  0.000005  0.004351 -0.051212 -0.001182 -0.000035  0.001140
#
#                max
# BNB-USD   0.697604
# BTC-USD   0.187465
# DOGE-USD  3.555466
# ETH-USD   0.259475
# ONE-USD   1.368370
# USDT-USD  0.054845

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#               mean       std
# BNB-USD   0.004411  0.062399
# BTC-USD   0.001477  0.039424
# DOGE-USD  0.005814  0.119581
# ETH-USD   0.002144  0.050973
# ONE-USD   0.001235  0.095922
# USDT-USD  0.000005  0.004351

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#               mean       std
# BNB-USD   1.111450  0.990559
# BTC-USD   0.372214  0.625839
# DOGE-USD  1.465021  1.898289
# ETH-USD   0.540167  0.809171
# ONE-USD   0.311124  1.522716
# USDT-USD  0.001212  0.069072

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize = 15)
plt.ylabel("Annual return",fontsize = 15)
plt.title("Risk/return",fontsize=25)
plt.show()

# %%
ret
# Out:
#              BNB-USD   BTC-USD  DOGE-USD   ETH-USD   ONE-USD      USDT-USD
# Date
# 2018-01-02  0.050289  0.097011  0.026490  0.144702  0.044919 -2.362812e-03
# 2018-01-03  0.078992  0.014611  0.019136  0.088503 -0.109649  8.498392e-03
# 2018-01-04 -0.033756  0.026196  0.034764  0.018907  0.100310 -1.076535e-02
# 2018-01-05  0.618973  0.117333  0.261613  0.017125  0.087624 -3.886166e-03
# 2018-01-06  0.525742  0.005594  0.221583  0.044061  0.384758  1.037023e-02
# ...              ...       ...       ...       ...       ...           ...
# 2022-01-26 -0.023046 -0.002757  0.005173  0.004925 -0.025000  2.597194e-05
# 2022-01-27  0.038144  0.007764 -0.017679 -0.018245  0.009158 -2.858030e-04
# 2022-01-28 -0.010264  0.017397  0.002896  0.051214  0.008469  9.533463e-07
# 2022-01-29  0.007896  0.009365  0.009883  0.019627 -0.000600  1.704105e-05
# 2022-01-30 -0.029604 -0.005784 -0.025060  0.002457 -0.043818 -2.097324e-05
#
# [1490 rows x 6 columns]

# %%
ret.cov()
# Out:
#            BNB-USD   BTC-USD  DOGE-USD   ETH-USD   ONE-USD  USDT-USD
# BNB-USD   0.003894  0.001536  0.001704  0.001986  0.001321 -0.000007
# BTC-USD   0.001536  0.001554  0.001596  0.001620  0.001076 -0.000002
# DOGE-USD  0.001704  0.001596  0.014300  0.001858  0.001663 -0.000005
# ETH-USD   0.001986  0.001620  0.001858  0.002598  0.001236 -0.000011
# ONE-USD   0.001321  0.001076  0.001663  0.001236  0.009201 -0.000023
# USDT-USD -0.000007 -0.000002 -0.000005 -0.000011 -0.000023  0.000019

# %%
ret.corr()
# Out:
#            BNB-USD   BTC-USD  DOGE-USD   ETH-USD   ONE-USD  USDT-USD
# BNB-USD   1.000000  0.624401  0.228363  0.624285  0.220669 -0.027528
# BTC-USD   0.624401  1.000000  0.338520  0.806104  0.284495 -0.012613
# DOGE-USD  0.228363  0.338520  1.000000  0.304868  0.145020 -0.009217
# ETH-USD   0.624285  0.806104  0.304868  1.000000  0.252889 -0.051020
# ONE-USD   0.220669  0.284495  0.145020  0.252889  1.000000 -0.056039
# USDT-USD -0.027528 -0.012613 -0.009217 -0.051020 -0.056039  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %%
df = pd.DataFrame(index=[2019,2020,2021],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2019    100
# 2020     50
# 2021     95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2020   -0.5
# 2021    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2020 -0.693147
# 2021  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
USDT_USD = yf.download("USDT-USD",start = "2018-01-01",end ="2022-01-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
USDT_USD
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 2018-01-01  1.012550  1.015360  1.001530  1.007280   1.007280   1685299968
# 2018-01-02  1.005740  1.009880  0.993250  1.004900   1.004900   2635859968
# 2018-01-03  1.006600  1.023280  1.002640  1.013440   1.013440   2471689984
# 2018-01-04  1.013200  1.016180  0.993822  1.002530   1.002530   3200130048
# 2018-01-05  1.001750  1.005010  0.985915  0.998634   0.998634   3096620032
# ...              ...       ...       ...       ...        ...          ...
# 2022-01-26  1.000595  1.001117  1.000290  1.000630   1.000630  70750980627
# 2022-01-27  1.000632  1.000859  1.000207  1.000344   1.000344  53950927548
# 2022-01-28  1.000343  1.000723  1.000151  1.000345   1.000345  50688257403
# 2022-01-29  1.000340  1.000633  1.000194  1.000362   1.000362  39357192812
# 2022-01-30  1.000455  1.000607  1.000234  1.000341   1.000341  35043713256
#
# [1491 rows x 6 columns]

# %%
usdt_usd=USDT_USD.Close.to_frame()

# %%
usdt_usd
# Out:
#                Close
# Date
# 2018-01-01  1.007280
# 2018-01-02  1.004900
# 2018-01-03  1.013440
# 2018-01-04  1.002530
# 2018-01-05  0.998634
# ...              ...
# 2022-01-26  1.000630
# 2022-01-27  1.000344
# 2022-01-28  1.000345
# 2022-01-29  1.000362
# 2022-01-30  1.000341
#
# [1491 rows x 1 columns]

# %%
usdt_usd.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
usdt_usd_roll=usdt_usd.rolling(window=10)

# %%
usdt_usd_roll=usdt_usd_roll.mean()

# %%
usdt_usd_roll.head(15)
# Out:
#                Close
# Date
# 2018-01-01       NaN
# 2018-01-02       NaN
# 2018-01-03       NaN
# 2018-01-04       NaN
# 2018-01-05       NaN
# 2018-01-06       NaN
# 2018-01-07       NaN
# 2018-01-08       NaN
# 2018-01-09       NaN
# 2018-01-10  1.005393
# 2018-01-11  1.004836
# 2018-01-12  1.004954
# 2018-01-13  1.003812
# 2018-01-14  1.005171
# 2018-01-15  1.005970

# %%
usdt_usd.rolling(window=10).median()
# Out:
#                Close
# Date
# 2018-01-01       NaN
# 2018-01-02       NaN
# 2018-01-03       NaN
# 2018-01-04       NaN
# 2018-01-05       NaN
# ...              ...
# 2022-01-26  1.000430
# 2022-01-27  1.000430
# 2022-01-28  1.000392
# 2022-01-29  1.000354
# 2022-01-30  1.000354
#
# [1491 rows x 1 columns]

# %%
usdt_usd.rolling(window=10).max()
# Out:
#               Close
# Date
# 2018-01-01      NaN
# 2018-01-02      NaN
# 2018-01-03      NaN
# 2018-01-04      NaN
# 2018-01-05      NaN
# ...             ...
# 2022-01-26  1.00063
# 2022-01-27  1.00063
# 2022-01-28  1.00063
# 2022-01-29  1.00063
# 2022-01-30  1.00063
#
# [1491 rows x 1 columns]

# %%
usdt_usd.rolling(window=10,min_periods=5).max()
# Out:
#               Close
# Date
# 2018-01-01      NaN
# 2018-01-02      NaN
# 2018-01-03      NaN
# 2018-01-04      NaN
# 2018-01-05  1.01344
# ...             ...
# 2022-01-26  1.00063
# 2022-01-27  1.00063
# 2022-01-28  1.00063
# 2022-01-29  1.00063
# 2022-01-30  1.00063
#
# [1491 rows x 1 columns]

# %%
usdt_usd
# Out:
#                Close
# Date
# 2018-01-01  1.007280
# 2018-01-02  1.004900
# 2018-01-03  1.013440
# 2018-01-04  1.002530
# 2018-01-05  0.998634
# ...              ...
# 2022-01-26  1.000630
# 2022-01-27  1.000344
# 2022-01-28  1.000345
# 2022-01-29  1.000362
# 2022-01-30  1.000341
#
# [1491 rows x 1 columns]

# %%
usdt_usd["SMA50"]=usdt_usd.rolling(window=50,min_periods=50).mean()

# %%
usdt_usd
# Out:
#                Close     SMA50
# Date
# 2018-01-01  1.007280       NaN
# 2018-01-02  1.004900       NaN
# 2018-01-03  1.013440       NaN
# 2018-01-04  1.002530       NaN
# 2018-01-05  0.998634       NaN
# ...              ...       ...
# 2022-01-26  1.000630  1.000384
# 2022-01-27  1.000344  1.000404
# 2022-01-28  1.000345  1.000393
# 2022-01-29  1.000362  1.000365
# 2022-01-30  1.000341  1.000361
#
# [1491 rows x 2 columns]

# %%
usdt_usd.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
usdt_usd["SMA200"]=usdt_usd.Close.rolling(window=200,min_periods=200).mean()
usdt_usd
# Out:
#                Close     SMA50    SMA200
# Date
# 2018-01-01  1.007280       NaN       NaN
# 2018-01-02  1.004900       NaN       NaN
# 2018-01-03  1.013440       NaN       NaN
# 2018-01-04  1.002530       NaN       NaN
# 2018-01-05  0.998634       NaN       NaN
# ...              ...       ...       ...
# 2022-01-26  1.000630  1.000384  1.000372
# 2022-01-27  1.000344  1.000404  1.000373
# 2022-01-28  1.000345  1.000393  1.000373
# 2022-01-29  1.000362  1.000365  1.000376
# 2022-01-30  1.000341  1.000361  1.000377
#
# [1491 rows x 3 columns]

# %%
usdt_usd.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
usdt_usd["EMA100"]=usdt_usd.Close.ewm(span=100,min_periods=100).mean()

# %%
usdt_usd
# Out:
#                Close     SMA50    SMA200    EMA100
# Date
# 2018-01-01  1.007280       NaN       NaN       NaN
# 2018-01-02  1.004900       NaN       NaN       NaN
# 2018-01-03  1.013440       NaN       NaN       NaN
# 2018-01-04  1.002530       NaN       NaN       NaN
# 2018-01-05  0.998634       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2022-01-26  1.000630  1.000384  1.000372  1.000400
# 2022-01-27  1.000344  1.000404  1.000373  1.000399
# 2022-01-28  1.000345  1.000393  1.000373  1.000397
# 2022-01-29  1.000362  1.000365  1.000376  1.000397
# 2022-01-30  1.000341  1.000361  1.000377  1.000396
#
# [1491 rows x 4 columns]

# %%
usdt_usd.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
usdt_usd["Day"]=usdt_usd.index.day_name()

# %%
usdt_usd["Quarter"]=usdt_usd.index.quarter

# %%
USDT_USD = yf.download("USDT-USD")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
usdt_usd=USDT_USD.Close.to_frame()

# %%
all_days=pd.date_range(start="2018-01-01",end="2022-01-31",freq="D")
all_days
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2022-01-22', '2022-01-23', '2022-01-24', '2022-01-25',
#                '2022-01-26', '2022-01-27', '2022-01-28', '2022-01-29',
#                '2022-01-30', '2022-01-31'],
#               dtype='datetime64[ns]', length=1492, freq='D')

# %%
usdt_usd
# Out:
#                Close
# Date
# 2017-11-09  1.008180
# 2017-11-10  1.006010
# 2017-11-11  1.008990
# 2017-11-12  1.012470
# 2017-11-13  1.009350
# ...              ...
# 2024-01-06  1.000592
# 2024-01-07  1.000607
# 2024-01-08  1.000599
# 2024-01-09  1.000166
# 2024-01-10  1.000412
#
# [2254 rows x 1 columns]

# %%
usdt_usd=usdt_usd.reindex(all_days)

# %%
usdt_usd
# Out:
#                Close
# 2018-01-01  1.007280
# 2018-01-02  1.004900
# 2018-01-03  1.013440
# 2018-01-04  1.002530
# 2018-01-05  0.998634
# ...              ...
# 2022-01-27  1.000344
# 2022-01-28  1.000345
# 2022-01-29  1.000362
# 2022-01-30  1.000341
# 2022-01-31  1.000485
#
# [1492 rows x 1 columns]

# %%
usdt_usd.fillna(method="ffill")
# Out:
#                Close
# 2018-01-01  1.007280
# 2018-01-02  1.004900
# 2018-01-03  1.013440
# 2018-01-04  1.002530
# 2018-01-05  0.998634
# ...              ...
# 2022-01-27  1.000344
# 2022-01-28  1.000345
# 2022-01-29  1.000362
# 2022-01-30  1.000341
# 2022-01-31  1.000485
#
# [1492 rows x 1 columns]

# %%
usdt_usd.fillna(method="bfill")
# Out:
#                Close
# 2018-01-01  1.007280
# 2018-01-02  1.004900
# 2018-01-03  1.013440
# 2018-01-04  1.002530
# 2018-01-05  0.998634
# ...              ...
# 2022-01-27  1.000344
# 2022-01-28  1.000345
# 2022-01-29  1.000362
# 2022-01-30  1.000341
# 2022-01-31  1.000485
#
# [1492 rows x 1 columns]

# %%
USDT_USD = yf.download("USDT-USD",interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
USDT_USD
# Out:
#                 Open      High       Low     Close  Adj Close        Volume
# Date
# 2017-11-06  1.010870  1.105910  0.967601  1.012470   1.012470    3326922016
# 2017-11-13  1.004480  1.029290  0.975103  1.002440   1.002440    4010979008
# 2017-11-20  1.001380  1.017420  0.988004  1.008680   1.008680    4445006944
# 2017-11-27  1.006750  1.048450  0.955618  1.000660   1.000660    6671386048
# 2017-12-04  1.002450  1.076950  0.971536  1.017750   1.017750    9677196032
# ...              ...       ...       ...       ...        ...           ...
# 2023-12-11  1.000072  1.001034  0.998572  0.999877   0.999877  342118113952
# 2023-12-18  0.999353  1.001344  0.998852  1.000880   1.000880  330892814297
# 2023-12-25  1.000781  1.001484  0.999325  0.999730   0.999730  357567035306
# 2024-01-01  0.999881  1.003630  0.999574  1.000607   1.000607  355688140156
# 2024-01-08  1.000714  1.001379  0.999423  1.000412   1.000412  186062994018
#
# [323 rows x 6 columns]

# %%
bitcoin = yf.download("BTC-USD", start="2018-01-01", end="2022-01-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
bitcoin=bitcoin.Close.to_frame()

# %%
bitcoin
# Out:
#                    Close
# Date
# 2018-01-01  13657.200195
# 2018-01-02  14982.099609
# 2018-01-03  15201.000000
# 2018-01-04  15599.200195
# 2018-01-05  17429.500000
# ...                  ...
# 2022-01-26  36852.121094
# 2022-01-27  37138.234375
# 2022-01-28  37784.332031
# 2022-01-29  38138.179688
# 2022-01-30  37917.601562
#
# [1491 rows x 1 columns]

# %%
bitcoin["d_returns"]=np.log(bitcoin.div(bitcoin.shift(1)))

# %%
bitcoin
# Out:
#                    Close  d_returns
# Date
# 2018-01-01  13657.200195        NaN
# 2018-01-02  14982.099609   0.092589
# 2018-01-03  15201.000000   0.014505
# 2018-01-04  15599.200195   0.025858
# 2018-01-05  17429.500000   0.110945
# ...                  ...        ...
# 2022-01-26  36852.121094  -0.002761
# 2022-01-27  37138.234375   0.007734
# 2022-01-28  37784.332031   0.017248
# 2022-01-29  38138.179688   0.009321
# 2022-01-30  37917.601562  -0.005800
#
# [1491 rows x 2 columns]

# %%
bitcoin.dropna(inplace=True)

# %%
bitcoin
# Out:
#                    Close  d_returns
# Date
# 2018-01-02  14982.099609   0.092589
# 2018-01-03  15201.000000   0.014505
# 2018-01-04  15599.200195   0.025858
# 2018-01-05  17429.500000   0.110945
# 2018-01-06  17527.000000   0.005578
# ...                  ...        ...
# 2022-01-26  36852.121094  -0.002761
# 2022-01-27  37138.234375   0.007734
# 2022-01-28  37784.332031   0.017248
# 2022-01-29  38138.179688   0.009321
# 2022-01-30  37917.601562  -0.005800
#
# [1490 rows x 2 columns]

# %%
bitcoin.d_returns.sum()
# Out:
# 1.021148556057615

# %%
np.exp(bitcoin.d_returns.sum())
# Out:
# 2.7763817634828443

# %%
bitcoin["cummreturns"]=bitcoin.d_returns.cumsum().apply(np.exp)

# %%
bitcoin
# Out:
#                    Close  d_returns  cummreturns
# Date
# 2018-01-02  14982.099609   0.092589     1.097011
# 2018-01-03  15201.000000   0.014505     1.113039
# 2018-01-04  15599.200195   0.025858     1.142196
# 2018-01-05  17429.500000   0.110945     1.276213
# 2018-01-06  17527.000000   0.005578     1.283352
# ...                  ...        ...          ...
# 2022-01-26  36852.121094  -0.002761     2.698366
# 2022-01-27  37138.234375   0.007734     2.719315
# 2022-01-28  37784.332031   0.017248     2.766624
# 2022-01-29  38138.179688   0.009321     2.792533
# 2022-01-30  37917.601562  -0.005800     2.776382
#
# [1490 rows x 3 columns]

# %%
bitcoin.cummreturns.plot(figsize=(12,8),title="Bitcoin buy and hold", fontsize=12)
plt.show()

# %%
bitcoin.d_returns.mean()*252
# Out:
# 0.17270431954799934

# %%
bitcoin.d_returns.std()*np.sqrt(252)
# Out:
# 0.6357864580814733

# %%
bitcoin["cummmax"]=bitcoin.cummreturns.cummax()

# %%
bitcoin
# Out:
#                    Close  d_returns  cummreturns   cummmax
# Date
# 2018-01-02  14982.099609   0.092589     1.097011  1.097011
# 2018-01-03  15201.000000   0.014505     1.113039  1.113039
# 2018-01-04  15599.200195   0.025858     1.142196  1.142196
# 2018-01-05  17429.500000   0.110945     1.276213  1.276213
# 2018-01-06  17527.000000   0.005578     1.283352  1.283352
# ...                  ...        ...          ...       ...
# 2022-01-26  36852.121094  -0.002761     2.698366  4.947341
# 2022-01-27  37138.234375   0.007734     2.719315  4.947341
# 2022-01-28  37784.332031   0.017248     2.766624  4.947341
# 2022-01-29  38138.179688   0.009321     2.792533  4.947341
# 2022-01-30  37917.601562  -0.005800     2.776382  4.947341
#
# [1490 rows x 4 columns]

# %%
bitcoin[["cummreturns","cummmax"]].plot(figsize=(12,8),title="Bitcoin buy and hold+cummmax", fontsize=12)
plt.show()

# %%
bitcoin["drawdown"]=bitcoin["cummmax"]-bitcoin["cummreturns"]

# %%
bitcoin
# Out:
#                    Close  d_returns  cummreturns   cummmax  drawdown
# Date
# 2018-01-02  14982.099609   0.092589     1.097011  1.097011  0.000000
# 2018-01-03  15201.000000   0.014505     1.113039  1.113039  0.000000
# 2018-01-04  15599.200195   0.025858     1.142196  1.142196  0.000000
# 2018-01-05  17429.500000   0.110945     1.276213  1.276213  0.000000
# 2018-01-06  17527.000000   0.005578     1.283352  1.283352  0.000000
# ...                  ...        ...          ...       ...       ...
# 2022-01-26  36852.121094  -0.002761     2.698366  4.947341  2.248975
# 2022-01-27  37138.234375   0.007734     2.719315  4.947341  2.228026
# 2022-01-28  37784.332031   0.017248     2.766624  4.947341  2.180718
# 2022-01-29  38138.179688   0.009321     2.792533  4.947341  2.154808
# 2022-01-30  37917.601562  -0.005800     2.776382  4.947341  2.170959
#
# [1490 rows x 5 columns]

# %%
bitcoin.drawdown.max()
# Out:
# 2.467277984734041

# %%
bitcoin.drawdown.idxmax()
# Out:
# Timestamp('2021-07-20 00:00:00')

# %%
bitcoin.loc[(bitcoin.index<='2020-09-18')]
# Out:
#                    Close  d_returns  cummreturns   cummmax  drawdown
# Date
# 2018-01-02  14982.099609   0.092589     1.097011  1.097011  0.000000
# 2018-01-03  15201.000000   0.014505     1.113039  1.113039  0.000000
# 2018-01-04  15599.200195   0.025858     1.142196  1.142196  0.000000
# 2018-01-05  17429.500000   0.110945     1.276213  1.276213  0.000000
# 2018-01-06  17527.000000   0.005578     1.283352  1.283352  0.000000
# ...                  ...        ...          ...       ...       ...
# 2020-09-14  10680.837891   0.034004     0.782066  1.283352  0.501286
# 2020-09-15  10796.951172   0.010813     0.790568  1.283352  0.492784
# 2020-09-16  10974.905273   0.016348     0.803598  1.283352  0.479754
# 2020-09-17  10948.990234  -0.002364     0.801701  1.283352  0.481651
# 2020-09-18  10944.585938  -0.000402     0.801378  1.283352  0.481974
#
# [991 rows x 5 columns]

# %%
bitcoin["drawdown%"]=(bitcoin["cummmax"]-bitcoin["cummreturns"])/bitcoin["cummmax"]

# %%
bitcoin
# Out:
#                    Close  d_returns  cummreturns   cummmax  drawdown  \
# Date
# 2018-01-02  14982.099609   0.092589     1.097011  1.097011  0.000000
# 2018-01-03  15201.000000   0.014505     1.113039  1.113039  0.000000
# 2018-01-04  15599.200195   0.025858     1.142196  1.142196  0.000000
# 2018-01-05  17429.500000   0.110945     1.276213  1.276213  0.000000
# 2018-01-06  17527.000000   0.005578     1.283352  1.283352  0.000000
# ...                  ...        ...          ...       ...       ...
# 2022-01-26  36852.121094  -0.002761     2.698366  4.947341  2.248975
# 2022-01-27  37138.234375   0.007734     2.719315  4.947341  2.228026
# 2022-01-28  37784.332031   0.017248     2.766624  4.947341  2.180718
# 2022-01-29  38138.179688   0.009321     2.792533  4.947341  2.154808
# 2022-01-30  37917.601562  -0.005800     2.776382  4.947341  2.170959
#
#             drawdown%
# Date
# 2018-01-02   0.000000
# 2018-01-03   0.000000
# 2018-01-04   0.000000
# 2018-01-05   0.000000
# ...

# %%
bitcoin["drawdown%"].max()
# Out:
# 0.8153271113852912

# %%
bitcoin["drawdown%"].idxmax()
# Out:
# Timestamp('2018-12-15 00:00:00')

# %%
bitcoin.loc[(bitcoin.index<='2022-02-01')]
# Out:
#                    Close  d_returns  cummreturns   cummmax  drawdown  \
# Date
# 2018-01-02  14982.099609   0.092589     1.097011  1.097011  0.000000
# 2018-01-03  15201.000000   0.014505     1.113039  1.113039  0.000000
# 2018-01-04  15599.200195   0.025858     1.142196  1.142196  0.000000
# 2018-01-05  17429.500000   0.110945     1.276213  1.276213  0.000000
# 2018-01-06  17527.000000   0.005578     1.283352  1.283352  0.000000
# ...                  ...        ...          ...       ...       ...
# 2022-01-26  36852.121094  -0.002761     2.698366  4.947341  2.248975
# 2022-01-27  37138.234375   0.007734     2.719315  4.947341  2.228026
# 2022-01-28  37784.332031   0.017248     2.766624  4.947341  2.180718
# 2022-01-29  38138.179688   0.009321     2.792533  4.947341  2.154808
# 2022-01-30  37917.601562  -0.005800     2.776382  4.947341  2.170959
#
#             drawdown%
# Date
# 2018-01-02   0.000000
# 2018-01-03   0.000000
# 2018-01-04   0.000000
# 2018-01-05   0.000000
# ...

# %%
data=bitcoin.Close.loc[(bitcoin.index>='2017-12-31')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                    Close
# Date
# 2018-01-02  14982.099609
# 2018-01-03  15201.000000
# 2018-01-04  15599.200195
# 2018-01-05  17429.500000
# 2018-01-06  17527.000000
# ...                  ...
# 2022-01-26  36852.121094
# 2022-01-27  37138.234375
# 2022-01-28  37784.332031
# 2022-01-29  38138.179688
# 2022-01-30  37917.601562
#
# [1490 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                    Close         sma_s         sma_l
# Date
# 2018-01-02  14982.099609           NaN           NaN
# 2018-01-03  15201.000000           NaN           NaN
# 2018-01-04  15599.200195           NaN           NaN
# 2018-01-05  17429.500000           NaN           NaN
# 2018-01-06  17527.000000           NaN           NaN
# ...                  ...           ...           ...
# 2022-01-26  36852.121094  44901.739062  52343.153828
# 2022-01-27  37138.234375  44634.407813  52071.916250
# 2022-01-28  37784.332031  44436.652031  51789.831211
# 2022-01-29  38138.179688  44254.549531  51549.111289
# 2022-01-30  37917.601562  44025.651406  51321.364648
#
# [1490 rows x 3 columns]

# %%
data.plot(figsize=(12,8),title="Bitcoin - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'Bitcoin - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2019"].plot(figsize=(12,8),title="Bitcoin - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'Bitcoin - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                    Close         sma_s         sma_l
# Date
# 2018-04-11   6968.319824   8768.319199  10136.625918
# 2018-04-12   7889.250000   8712.296191  10065.697422
# 2018-04-13   7895.959961   8670.115391   9992.647021
# 2018-04-14   7986.240234   8623.818203   9916.517422
# 2018-04-15   8329.110352   8594.139004   9825.513525
# ...                  ...           ...           ...
# 2022-01-26  36852.121094  44901.739062  52343.153828
# 2022-01-27  37138.234375  44634.407813  52071.916250
# 2022-01-28  37784.332031  44436.652031  51789.831211
# 2022-01-29  38138.179688  44254.549531  51549.111289
# 2022-01-30  37917.601562  44025.651406  51321.364648
#
# [1391 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                    Close         sma_s         sma_l  position
# Date
# 2018-04-11   6968.319824   8768.319199  10136.625918        -1
# 2018-04-12   7889.250000   8712.296191  10065.697422        -1
# 2018-04-13   7895.959961   8670.115391   9992.647021        -1
# 2018-04-14   7986.240234   8623.818203   9916.517422        -1
# 2018-04-15   8329.110352   8594.139004   9825.513525        -1
# ...                  ...           ...           ...       ...
# 2022-01-26  36852.121094  44901.739062  52343.153828        -1
# 2022-01-27  37138.234375  44634.407813  52071.916250        -1
# 2022-01-28  37784.332031  44436.652031  51789.831211        -1
# 2022-01-29  38138.179688  44254.549531  51549.111289        -1
# 2022-01-30  37917.601562  44025.651406  51321.364648        -1
#
# [1391 rows x 4 columns]

# %%
data.loc["2019",["sma_s","sma_l","position"]].plot(figsize=(12,8),title="Bitcoin - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'Bitcoin - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                    Close         sma_s         sma_l  position  returnsb&h  \
# Date
# 2018-04-11   6968.319824   8768.319199  10136.625918        -1         NaN
# 2018-04-12   7889.250000   8712.296191  10065.697422        -1    0.124127
# 2018-04-13   7895.959961   8670.115391   9992.647021        -1    0.000850
# 2018-04-14   7986.240234   8623.818203   9916.517422        -1    0.011369
# 2018-04-15   8329.110352   8594.139004   9825.513525        -1    0.042037
# ...                  ...           ...           ...       ...         ...
# 2022-01-26  36852.121094  44901.739062  52343.153828        -1   -0.002761
# 2022-01-27  37138.234375  44634.407813  52071.916250        -1    0.007734
# 2022-01-28  37784.332031  44436.652031  51789.831211        -1    0.017248
# 2022-01-29  38138.179688  44254.549531  51549.111289        -1    0.009321
# 2022-01-30  37917.601562  44025.651406  51321.364648        -1   -0.005800
#
#             strategy
# Date
# 2018-04-11       NaN
# ...

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    1.694041
# strategy      1.438790
# dtype: float64

# %%
data[["returnsb&h","strategy"]].sum().apply(np.exp)
# Out:
# returnsb&h    5.441427
# strategy      4.215591
# dtype: float64

# %%
data[["returnsb&h","strategy"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.607897
# strategy      0.607983
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy2"]].sum()
# Out:
# returnsb&h    1.569914
# strategy2     1.566416
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp)
# Out:
# returnsb&h    4.806237
# strategy2     4.789450
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.605855
# strategy2     0.488939
# dtype: float64

# %%
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.605858
# strategy2    0.488939
# dtype: float64

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std= data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy("USDT-USD","2018-01-01","2022-01-31",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (0.9117182422393512, 0.06574516772453295)

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        df = yf.download(self.symbol, start=self.start, end=self.end)
        data = df.Close.to_frame()
        data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"] = data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"] = data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2 = data
        return data

    def test_results(self, transaction_cost_rate=0.0015):
        data = self.data2.copy().dropna()
        data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)

       
        data["transaction_cost"] = transaction_cost_rate * abs(data["position"] - data["position"].shift(1))
        data["slippage"] = transaction_cost_rate * data["position"].shift(1)

        
        data["strategy"] = data["returns"] * data["position"] - data["transaction_cost"] - data["slippage"]
        data.dropna(inplace=True)

        data["returnsbh"] = data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"] = data["strategy"].cumsum().apply(np.exp)
        perf = data["returnsstrategy"].iloc[-1]
        outperf = perf - data["returnsbh"].iloc[-1]
        self.results = data

        ret = np.exp(data["strategy"].sum())
        std = data["strategy"].std() * np.sqrt(252)

        return round(perf, 6), round(outperf, 6)

    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title = "{}| SMA_S={} | SMA_L{}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["returnsbh", "returnsstrategy"]].plot(title=title, figsize=(12, 8))

# %%
tester= SMABacktester("USDT-USD",50,100, "2018-01-01","2022-01-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (1.047023, 0.04403)

# %%
tester.plot_results()

# %%
tester= SMABacktester("BTC-USD",50,100, "2018-01-01","2022-01-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (4.764718, -0.783041)

# %%
tester.plot_results()

# %%
tester= SMABacktester("BTC-USD",1,200, "2018-01-01","2022-01-31")
tester.test_results()
tester.plot_results()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import time

def my_model(input_data):
    # Simulate some processing time
    time.sleep(0.1)
    return input_data * 2

# Measure the time taken for the function to execute
start_time = time.time()
result = my_model(5)
end_time = time.time()

duration = end_time - start_time
print(f"Duration time: {duration:.4f} seconds")
# Out:
# Duration time: 0.1042 seconds
